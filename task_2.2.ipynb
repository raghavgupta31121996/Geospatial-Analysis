# %% [markdown]
# St20183508
#
# # Geospatial Analysis
#
# ## Task 2.2

# %%
import geopandas as gpd
import pandas as pd

# %%
Total_P = gpd.read_file('Data_Total_Population.shp')
Total_P.head()
# Out:
#              Country Na Country Co          Indicator   Indicato_1  \
# 0           Afghanistan        AFG  Population, total  SP.POP.TOTL
# 1                Angola        AGO  Population, total  SP.POP.TOTL
# 2               Albania        ALB  Population, total  SP.POP.TOTL
# 3  United Arab Emirates        ARE  Population, total  SP.POP.TOTL
# 4             Argentina        ARG  Population, total  SP.POP.TOTL
#
#          1960        1961        1962        1963        1964        1965  \
# 0   8996973.0   9169410.0   9351441.0   9543205.0   9744781.0   9956320.0
# 1   5454933.0   5531472.0   5608539.0   5679458.0   5735044.0   5770570.0
# 2   1608800.0   1659800.0   1711319.0   1762621.0   1814135.0   1864791.0
# 3     92418.0    100796.0    112118.0    125130.0    138039.0    149857.0
# 4  20481779.0  20817266.0  21153052.0  21488912.0  21824425.0  22159650.0
#
#    ...        2014        2015        2016        2017        2018  \
# ...

# %% [markdown]
# # 1)

# %% [markdown]
# ### For year 2010, plot the urban population per capita for only the countries having population greater than 290000000. Very briefly interpret the generated plot.

# %%
countries=Total_P[Total_P['2010']>290000000]
countries.head()
# Out:
#         Country Na Country Co          Indicator   Indicato_1         1960  \
# 28           China        CHN  Population, total  SP.POP.TOTL  667070000.0
# 67           India        IND  Population, total  SP.POP.TOTL  450547679.0
# 154  United States        USA  Population, total  SP.POP.TOTL  180671000.0
#
#             1961         1962         1963         1964         1965  ...  \
# 28   660330000.0  665770000.0  682335000.0  698355000.0  715185000.0  ...
# 67   459642165.0  469077190.0  478825608.0  488848135.0  499123324.0  ...
# 154  183691000.0  186538000.0  189242000.0  191889000.0  194303000.0  ...
#
#              2014          2015          2016          2017          2018  \
# 28   1.364270e+09  1.371220e+09  1.378665e+09  1.386395e+09  1.392730e+09
# 67   1.295604e+09  1.310152e+09  1.324510e+09  1.338659e+09  1.352617e+09
# 154  3.183010e+08  3.206352e+08  3.229413e+08  3.249855e+08  3.266875e+08
#
#              2019  UBPC_1990  UBPC_2000  UBPC_2010  \
# ...

# %%
from mpl_toolkits.axes_grid1 import make_axes_locatable
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, 1)
divider = make_axes_locatable(ax)

cax = divider.append_axes("right", size="5%", pad=0.1)

countries.plot(column='UBPC_2010', ax=ax, legend=True, cax=cax,legend_kwds={'label': "Urban Population Per Capita"})
# Out:
# <AxesSubplot:>

# %% [markdown]
# The countries which had population greater than 290000000 in 2010 were India, China and United States of America.
#
# The above map plots the urban population per capita of these countries. It is evident that India had the lowest
#
# urban population per capita of 0.30930 (purple) , followed by China with 0.49226 (blue) and USA with the highest of
#
# 0.80772 (yellow) in year 2010. This confirms the fact that USA has been a more developed economy as compared to
#
# China and India. This is because, in USA, there is higher demographic transition from rural to urban areas where
#
# there are more job opportunities and other social benefits to improve there standard of living, than China and India.

# %% [markdown]
# # 2)

# %% [markdown]
# ### For year 2010, plot the urban population per capita for only the countries having population less than 69000000. Very briefly interpret the generated plot.

# %%
countries1=Total_P[Total_P['2010']<69000000]
countries1
# Out:
#                Country Na Country Co          Indicator   Indicato_1  \
# 0             Afghanistan        AFG  Population, total  SP.POP.TOTL
# 1                  Angola        AGO  Population, total  SP.POP.TOTL
# 2                 Albania        ALB  Population, total  SP.POP.TOTL
# 3    United Arab Emirates        ARE  Population, total  SP.POP.TOTL
# 4               Argentina        ARG  Population, total  SP.POP.TOTL
# ..                    ...        ...                ...          ...
# 158               Vanuatu        VUT  Population, total  SP.POP.TOTL
# 159           Yemen, Rep.        YEM  Population, total  SP.POP.TOTL
# 160          South Africa        ZAF  Population, total  SP.POP.TOTL
# 161                Zambia        ZMB  Population, total  SP.POP.TOTL
# 162              Zimbabwe        ZWE  Population, total  SP.POP.TOTL
#
#            1960        1961        1962        1963        1964        1965  \
# ...

# %%
minValue = countries1[countries1['UBPC_2010']==countries1['UBPC_2010'].min()]
minValue
# Out:
#   Country Na Country Co          Indicator   Indicato_1       1960       1961  \
# 9    Burundi        BDI  Population, total  SP.POP.TOTL  2797932.0  2852438.0
#
#         1962       1963       1964       1965  ...       2014        2015  \
# 9  2907321.0  2964427.0  3026290.0  3094379.0  ...  9844297.0  10160030.0
#
#          2016        2017        2018        2019  UBPC_1990  UBPC_2000  \
# 9  10487998.0  10827024.0  11175378.0  11530580.0    0.06271    0.08246
#
#    UBPC_2010                                           geometry
# 9    0.10642  POLYGON ((3391868.555 -266990.291, 3398323.566...
#
# [1 rows x 68 columns]

# %%
maxValue = countries1[countries1['UBPC_2010']==countries1['UBPC_2010'].max()]
maxValue
# Out:
#     Country Na Country Co          Indicator   Indicato_1     1960     1961  \
# 123      Qatar        QAT  Population, total  SP.POP.TOTL  47384.0  51421.0
#
#         1962     1963     1964     1965  ...       2014       2015       2016  \
# 123  56262.0  61716.0  67566.0  73633.0  ...  2459198.0  2565710.0  2654374.0
#
#           2017       2018       2019  UBPC_1990  UBPC_2000  UBPC_2010  \
# 123  2724724.0  2781677.0  2832067.0   0.927859    0.96311    0.98501
#
#                                               geometry
# 123  POLYGON ((5656155.380 2827764.198, 5648786.307...
#
# [1 rows x 68 columns]

# %%
from mpl_toolkits.axes_grid1 import make_axes_locatable
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, 1)
divider = make_axes_locatable(ax)

cax = divider.append_axes("right", size="5%", pad=0.1)

countries1.plot(column='UBPC_2010', ax=ax, legend=True, cax=cax,legend_kwds={'label': "Urban Population Per Capita"})
# Out:
# <AxesSubplot:>

# %% [markdown]
# In 2010, 145 countries had population less than 69000000. The above map plots the urban population per capita of
#
# these countries. It can be inferred that Burundi had the lowest (0.10642) and Qatar had the highest (0.98501) urban
#
# population per capita in 2010. Also, other countries on average had urban population per capita between 0.4 and
#
# 0.8. This shows that less populated countries had moderate urban population per capita in 2010. Additionally, in
#
# the map, the developed countries such as Canada, Denmark, Australia, Sweden, Argentina have higher urban population
#
# per capita as compared to the developing countries such as Nigeria, Ethopia, Kenya, Pakistan and Afghanistan.

# %% [markdown]
# # 3)

# %% [markdown]
# ### For year 2010, plot the urban population per capita for only the countries having urban population between 110146163 and 223096279. Very briefly interpret the generated plot.

# %%
Urban_P = gpd.read_file('Data_Urban_Population.shp')
Urban_P.head()
# Out:
#              Country Na Country Co         Indicator   Indicato_1        1960  \
# 0           Afghanistan        AFG  Urban population  SP.URB.TOTL    755836.0
# 1                Angola        AGO  Urban population  SP.URB.TOTL    569222.0
# 2               Albania        ALB  Urban population  SP.URB.TOTL    493982.0
# 3  United Arab Emirates        ARE  Urban population  SP.URB.TOTL     67927.0
# 4             Argentina        ARG  Urban population  SP.URB.TOTL  15076842.0
#
#          1961        1962        1963        1964        1965  ...  \
# 0    796272.0    839385.0    885228.0    934135.0    986074.0  ...
# 1    597288.0    628381.0    660180.0    691532.0    721552.0  ...
# 2    513592.0    530766.0    547928.0    565248.0    582374.0  ...
# 3     74975.0     84367.0     95215.0    106178.0    116473.0  ...
# 4  15449950.0  15815502.0  16183085.0  16552517.0  16923103.0  ...
#
#          2014        2015        2016        2017        2018        2019  \
# ...

# %%
countries2=Urban_P[(Urban_P['2010']>110146163) & (Urban_P['2010']<223096279)]
countries2
# Out:
#    Country Na Country Co         Indicator   Indicato_1        1960  \
# 20     Brazil        BRA  Urban population  SP.URB.TOTL  33302773.0
# 66  Indonesia        IDN  Urban population  SP.URB.TOTL  12799371.0
# 76      Japan        JPN  Urban population  SP.URB.TOTL  58526962.0
#
#           1961        1962        1963        1964        1965  ...  \
# 20  35016991.0  36802627.0  38660045.0  40580114.0  42551349.0  ...
# 66  13353483.0  13931417.0  14536390.0  15169460.0  15831166.0  ...
# 76  60965749.0  62428798.0  63957880.0  65516029.0  67107937.0  ...
#
#            2014         2015         2016         2017         2018  \
# 20  173346772.0  175375436.0  177386818.0  179379301.0  181335507.0
# 66  134287151.0  137751865.0  141210511.0  144652795.0  148084795.0
# 76  116208079.0  116182717.0  116145370.0  116053379.0  115920900.0
#
#            2019  UBPC_1990  UBPC_2000  UBPC_2010  \
# 20  183241641.0    0.73922    0.81192    0.84335
# ...

# %%
from mpl_toolkits.axes_grid1 import make_axes_locatable
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, 1)
divider = make_axes_locatable(ax)

cax = divider.append_axes("right", size="5%", pad=0.1)

countries2.plot(column='UBPC_2010', ax=ax, legend=True, cax=cax,legend_kwds={'label': "Urban Population Per Capita"})
# Out:
# <AxesSubplot:>

# %% [markdown]
# The countries which had urban Population between 110146163 and 223096279 in 2010 are Brazil, Indonesia and Japan.
#
# The above map plots the urban population per capita of these countries in 2010. The map shows that out of these
#
# countries, Japan being the most developed country had the highest urban population per capita of 0.90812, followed
#
# by Brazil with 0.84335 and then Indonesia with the lowest of 0.49914. This means that 80 to 90 percent of the total
#
# population in Japan and Brazil are living in urban areas whereas, in Indonesia olny 50 percent of the total
#
# population is living in urban areas in 2010. This shows that majority of people in Japan and Brazil had access to
#
# better social and environmental facilities as compared to Indonesia.

# %% [markdown]
# # 4)

# %% [markdown]
# ### What is the percentage change in the urban population per capita from 1990 to 2010, for the country having the highest population in 2010? In this question, you have to consider the urban population per capita for only two years: 1990 and 2010. Thereafter, you are required to find the percentage change.

# %%
countries3 = Total_P[Total_P['2010']==Total_P['2010'].max()]
countries3
# Out:
#    Country Na Country Co          Indicator   Indicato_1         1960  \
# 28      China        CHN  Population, total  SP.POP.TOTL  667070000.0
#
#            1961         1962         1963         1964         1965  ...  \
# 28  660330000.0  665770000.0  682335000.0  698355000.0  715185000.0  ...
#
#             2014          2015          2016          2017          2018  \
# 28  1.364270e+09  1.371220e+09  1.378665e+09  1.386395e+09  1.392730e+09
#
#             2019  UBPC_1990  UBPC_2000  UBPC_2010  \
# 28  1.397715e+09    0.26442    0.35877    0.49226
#
#                                              geometry
# 28  MULTIPOLYGON (((12186724.586 2047364.867, 1209...
#
# [1 rows x 68 columns]

# %%
countries3['Percentage Change'] = (countries3.UBPC_2010 - countries3.UBPC_1990) / countries3.UBPC_1990
countries3
# Out:
# /Users/raghavgupta/opt/anaconda3/lib/python3.8/site-packages/geopandas/geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
#    Country Na Country Co          Indicator   Indicato_1         1960  \
# 28      China        CHN  Population, total  SP.POP.TOTL  667070000.0
#
#            1961         1962         1963         1964         1965  ...  \
# 28  660330000.0  665770000.0  682335000.0  698355000.0  715185000.0  ...
#
#             2015          2016          2017          2018          2019  \
# 28  1.371220e+09  1.378665e+09  1.386395e+09  1.392730e+09  1.397715e+09
#
#     UBPC_1990  UBPC_2000  UBPC_2010  \
# 28    0.26442    0.35877    0.49226
#
# ...

# %% [markdown]
# In 2010, China had the highest population in the world. From 1990 to 2010, the percentage change in the urban
#
# population per capita of China was 86.16%. This shows that in these two decades, China saw a major demographic
#
# shift of the population from rural to urban areas. This means that more people in China were moving to the
#
# developed areas of the country in order to have better standard of living. This also shows that the China economy
#
# was booming in 2010 and shifting towards industrial/technical-based market. Lastly, it can be infered that in these
#
# two decades, as the total population of China increased, the urban population per capita also increased at a considerable rate.

# %% [markdown]
# # 5)

# %% [markdown]
# ### Plot the mean per capita world urban population (from 1990 to 2010) of all the countries. Very briefly interpret the generated plot. In this question, you have to consider the world urban population per capita for each year between 1990 and 2010 for calculating their mean values.

# %%
a = {Urban_P.columns.get_loc(c): c for idx, c in enumerate(Urban_P.columns)}
a
# Out:
# {0: 'Country Na',
#  1: 'Country Co',
#  2: 'Indicator',
#  3: 'Indicato_1',
#  4: '1960',
#  5: '1961',
#  6: '1962',
#  7: '1963',
#  8: '1964',
#  9: '1965',
#  10: '1966',
#  11: '1967',
#  12: '1968',
#  13: '1969',
#  14: '1970',
#  15: '1971',
#  16: '1972',
#  17: '1973',
#  18: '1974',
#  19: '1975',
#  20: '1976',
#  21: '1977',
#  22: '1978',
#  23: '1979',
#  24: '1980',
#  25: '1981',
#  26: '1982',
#  27: '1983',
#  28: '1984',
#  29: '1985',
#  30: '1986',
#  31: '1987',
#  32: '1988',
#  33: '1989',
#  34: '1990',
#  35: '1991',
#  36: '1992',
#  37: '1993',
#  38: '1994',
#  39: '1995',
#  40: '1996',
#  41: '1997',
#  42: '1998',
#  43: '1999',
#  44: '2000',
#  45: '2001',
#  46: '2002',
#  47: '2003',
#  48: '2004',
#  49: '2005',
#  50: '2006',
#  51: '2007',
#  52: '2008',
#  53: '2009',
#  54: '2010',
#  55: '2011',
#  56: '2012',
#  57: '2013',
#  58: '2014',
#  59: '2015',
#  60: '2016',
#  61: '2017',
#  62: '2018',
#  63: '2019',
#  64: 'UBPC_1990',
# ...

# %%
Urban_P['MPC_WUP']= ((Urban_P.iloc[:,34:55]) / (Total_P.iloc[:,34:55])).mean(axis=1)
Urban_P.head()
# Out:
#              Country Na Country Co         Indicator   Indicato_1        1960  \
# 0           Afghanistan        AFG  Urban population  SP.URB.TOTL    755836.0
# 1                Angola        AGO  Urban population  SP.URB.TOTL    569222.0
# 2               Albania        ALB  Urban population  SP.URB.TOTL    493982.0
# 3  United Arab Emirates        ARE  Urban population  SP.URB.TOTL     67927.0
# 4             Argentina        ARG  Urban population  SP.URB.TOTL  15076842.0
#
#          1961        1962        1963        1964        1965  ...  \
# 0    796272.0    839385.0    885228.0    934135.0    986074.0  ...
# 1    597288.0    628381.0    660180.0    691532.0    721552.0  ...
# 2    513592.0    530766.0    547928.0    565248.0    582374.0  ...
# 3     74975.0     84367.0     95215.0    106178.0    116473.0  ...
# 4  15449950.0  15815502.0  16183085.0  16552517.0  16923103.0  ...
#
#          2015        2016        2017        2018        2019  UBPC_1990  \
# ...

# %%
MinValue = Urban_P[Urban_P['MPC_WUP']==Urban_P['MPC_WUP'].min()]
MinValue
# Out:
#   Country Na Country Co         Indicator   Indicato_1     1960     1961  \
# 9    Burundi        BDI  Urban population  SP.URB.TOTL  58113.0  60329.0
#
#       1962     1963     1964     1965  ...       2015       2016       2017  \
# 9  62624.0  65010.0  67577.0  70985.0  ...  1227128.0  1299253.0  1375682.0
#
#         2018       2019  UBPC_1990  UBPC_2000  UBPC_2010  \
# 9  1456375.0  1541177.0    0.06271    0.08246    0.10642
#
#                                             geometry   MPC_WUP
# 9  POLYGON ((3391868.555 -266990.291, 3398323.566...  0.083207
#
# [1 rows x 69 columns]

# %%
MaxValue = Urban_P[Urban_P['MPC_WUP']==Urban_P['MPC_WUP'].max()]
MaxValue
# Out:
#    Country Na Country Co         Indicator   Indicato_1       1960       1961  \
# 10    Belgium        BEL  Urban population  SP.URB.TOTL  8463316.0  8500111.0
#
#          1962       1963       1964       1965  ...        2015        2016  \
# 10  8545539.0  8624158.0  8720520.0  8814176.0  ...  11034732.0  11095615.0
#
#           2017        2018        2019  UBPC_1990  UBPC_2000  UBPC_2010  \
# 10  11143219.0  11198627.0  11259082.0    0.96377    0.97129    0.97651
#
#                                              geometry   MPC_WUP
# 10  POLYGON ((685356.051 6553512.874, 672711.849 6...  0.970804
#
# [1 rows x 69 columns]

# %%
from mpl_toolkits.axes_grid1 import make_axes_locatable
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, 1)
divider = make_axes_locatable(ax)

cax = divider.append_axes("right", size="5%", pad=0.1)

Urban_P.plot(column='MPC_WUP', ax=ax, legend=True, cax=cax,legend_kwds={'label': " Mean Per Capita World Urban Population"})
# Out:
# <AxesSubplot:>

# %% [markdown]
# The above map plots the mean per capita world urban population from to 1990 to 2010 of all the countries. The map
#
# shows that the highest and lowest average urban population per capita was of Belgium (0.970804) and Burundi
#
# (0.083207) respectively, between 1990 and 2010. This shows there was a lot of difference between the mean urban
#
# population per capita of the countries. Less developed countries (Asia and Africa) had lower mean urban population
#
# per capita as compared to more developed countries (Europe, America and Australia). Most of the countries, on
#
# average, had urban population per capita between 40 to 80 percent in these two decades.This means that there has
#
# been a gradual shift in share of total population living in urban areas as the economy starts growing and developing from 1990 to 2010.

# %% [markdown]
# # 6)

# %% [markdown]
# ### Present a correlation plot between mean world population and mean per capita world urban population (from 1990 to 2010). Very briefly interpret the generated plot. In this question, you have to consider each year between 1990 and 2010 to find the mean population and mean per capita urban population.

# %%
Total_P['Mean_Total'] = Total_P.iloc[:,34:55].mean(axis=1)
Total_P.head()
# Out:
#              Country Na Country Co          Indicator   Indicato_1  \
# 0           Afghanistan        AFG  Population, total  SP.POP.TOTL
# 1                Angola        AGO  Population, total  SP.POP.TOTL
# 2               Albania        ALB  Population, total  SP.POP.TOTL
# 3  United Arab Emirates        ARE  Population, total  SP.POP.TOTL
# 4             Argentina        ARG  Population, total  SP.POP.TOTL
#
#          1960        1961        1962        1963        1964        1965  \
# 0   8996973.0   9169410.0   9351441.0   9543205.0   9744781.0   9956320.0
# 1   5454933.0   5531472.0   5608539.0   5679458.0   5735044.0   5770570.0
# 2   1608800.0   1659800.0   1711319.0   1762621.0   1814135.0   1864791.0
# 3     92418.0    100796.0    112118.0    125130.0    138039.0    149857.0
# 4  20481779.0  20817266.0  21153052.0  21488912.0  21824425.0  22159650.0
#
#    ...        2015        2016        2017        2018        2019  UBPC_1990  \
# ...

# %%
Urban_P['correlation'] = Total_P['Mean_Total'].corr(Urban_P['MPC_WUP'])
Urban_P.head()
# Out:
#              Country Na Country Co         Indicator   Indicato_1        1960  \
# 0           Afghanistan        AFG  Urban population  SP.URB.TOTL    755836.0
# 1                Angola        AGO  Urban population  SP.URB.TOTL    569222.0
# 2               Albania        ALB  Urban population  SP.URB.TOTL    493982.0
# 3  United Arab Emirates        ARE  Urban population  SP.URB.TOTL     67927.0
# 4             Argentina        ARG  Urban population  SP.URB.TOTL  15076842.0
#
#          1961        1962        1963        1964        1965  ...  \
# 0    796272.0    839385.0    885228.0    934135.0    986074.0  ...
# 1    597288.0    628381.0    660180.0    691532.0    721552.0  ...
# 2    513592.0    530766.0    547928.0    565248.0    582374.0  ...
# 3     74975.0     84367.0     95215.0    106178.0    116473.0  ...
# 4  15449950.0  15815502.0  16183085.0  16552517.0  16923103.0  ...
#
#          2016        2017        2018        2019  UBPC_1990  UBPC_2000  \
# ...

# %%
result = pd.concat([Urban_P['MPC_WUP'], Total_P['Mean_Total']], axis=1)
result
# Out:
#       MPC_WUP    Mean_Total
# 0    0.222128  2.129546e+07
# 1    0.496477  1.683680e+07
# 2    0.429190  3.095489e+06
# 3    0.806279  3.857189e+06
# 4    0.890745  3.683281e+07
# ..        ...           ...
# 158  0.216376  1.883747e+05
# 159  0.263220  1.745547e+07
# 160  0.570134  4.455899e+07
# 161  0.371357  1.054246e+07
# 162  0.327325  1.173322e+07
#
# [163 rows x 2 columns]

# %%
import seaborn as sns
plt.figure(figsize=(12,6))
ax = sns.heatmap(result.corr(),cmap='coolwarm',annot=True)

# %%
plt.scatter(Urban_P['MPC_WUP'], Total_P['Mean_Total'])
plt.title('Correlation Plot from 1990 to 2010')
plt.xlabel('Mean per capita world urban population')
plt.ylabel('Mean population')
plt.show()

# %% [markdown]
# The above figures depicts the correlation heat map and a scatter plot between mean world population and mean per capita world urban
#
# population from 1990 to 2010. Correlation plot shows how a percent change in mean world population can affect the
#
# mean per capita world urban population. The plot exhibits that there is a negative correlation of -0.082 between
#
# the two. This means that on average as the total population increases the mean per capita world urban population
#
# decreases by 8.2%. It can be infered that between 1990 and 2010 there was a higher world rural population than
#
# world urban population on average which lead to increase in the total world population. As the mean world
#
# population rises, it becomes difficult to shift to urban areas and also for the country to provide facilities to everyone.
